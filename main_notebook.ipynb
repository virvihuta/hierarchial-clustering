# %% [markdown]
# # Hierarchical Clustering
#
# Hierarchisches Clustering ist eine unüberwachte Lernmethode, die Datenpunkte anhand ihrer Ähnlichkeit (in der Regel gemessen anhand des Abstands) gruppiert.
# Im Gegensatz zu k-Means müssen Sie dabei nicht vorab die Anzahl der Cluster festlegen. Stattdessen wird Schritt für Schritt eine Hierarchie von Clustern aufgebaut.
#
# Beim agglomerativen hierarchischen Clustering (Bottom-up-Ansatz):
#
# - Jeder Datenpunkt beginnt als eigener Cluster.
# - Die beiden nächstgelegenen Cluster werden zusammengeführt.
# - Dieser Vorgang wiederholt sich, bis nur noch ein Cluster übrig bleibt.
#
# Das Ergebnis kann mithilfe eines Dendrogramms visualisiert werden, das zeigt, wie Cluster zusammengeführt wurden und in welchen Abständen.
#
# Das werden wir heute programmieren, also schnallen Sie sich an und viel Spaß dabei! 😊

# %% [markdown]
# ![Stacked Bar Plot Meme](meme.jpg)

# %% [markdown]
# ##### Meme Hilfe:
#
# Wenn du dieses Meme nicht verstehst, hier ist die einfache Erklärung:
#
# Ein gestapeltes Balkendiagramm ist normalerweise etwas ganz Einfaches. Man benutzt es, um Daten übersichtlich darzustellen.
# Hierarchisches Clustering mit einem Dendrogramm ist dagegen eine eher komplizierte Methode aus der Datenanalyse.
# Das Meme ist lustig, weil es so tut, als wäre die Kombination von beiden etwas extrem Besonderes und Beeindruckendes. In Wirklichkeit wird etwas Einfaches nur unnötig kompliziert gemacht.
#
# Der Witz dahinter ist typisch für die Datenwissenschaft:
#
# Manchmal werden Dinge sehr technisch erklärt oder dargestellt, damit sie wichtiger oder schlauer wirken, als sie eigentlich sind.

# %%
# Wird verwendet, um numerische Arrays wie X zu erstellen und zu bearbeiten und mathematische Operationen effizient durchzuführen.
import numpy as np

# Wird zur Visualisierung von Daten verwendet, beispielsweise zum Zeichnen von Streudiagrammen oder Clustering-Ergebnissen.
import matplotlib.pyplot as plt

# Wird verwendet, um das Dendrogramm zu generieren und anzuzeigen, das die hierarchische Clustering-Struktur visualisiert.
from scipy.cluster.hierarchy import dendrogram

# %%
# Ein NumPy-Array, das 2D-Datenpunkte enthält.
X = np.array([
    [1, 1],
    [1.5, 1.5],
    [5, 5],
    [6, 5],
    [8, 8],
    [9, 8]
])

# %%
# TODO: Die Form des Arrays ausdrucken
shape = ...
print(shape)
# Out:
# Ellipsis

# %% [markdown]
# ### Hilfe:
#
# In einem Streudiagramm liefert X[:, 0] die x-Koordinaten (erstes Merkmal aller Stichproben) und X[:, 1] die y-Koordinaten (zweites Merkmal aller Stichproben).

# %%
# TODO: Zeichnen Sie die Datenpunkte mit matplotlib
...

# %% [markdown]
# ## Berechnen Sie den euklidischen Abstand.
#
# Der euklidische Abstand misst die Entfernung in gerader Linie zwischen zwei Punkten.

# %% [markdown]
# $$
# d(A, B) = \sqrt{(x_2 - x_1)^2 + (y_2 - y_1)^2}
# $$
#
# Wo:
# - $A = (x_1, y_1)$
# - $B = (x_2, y_2)$
# - Subtrahiere die Koordinaten, quadriere sie, addiere sie und ziehe dann die Quadratwurzel.

# %%
def euclidean_distance(a, b):
    #TODO: Berechnen Sie den euklidischen Abstand.
    return ...

# %% [markdown]
# ## Implementieren Sie Single-Linkage-Clusterdistanz für hierarchisches Clustering.
#
# Sie erhalten:
# - `cluster1` → eine Liste von Punkten
# - `cluster2` → eine weitere Liste von Punkten
# - `euclidean_distance(p1, p2)` bereits umgesetzt
#
# <br>
#
# Ihre Aufgabe in diesem Code ist es:
# - Vergleiche jeden Punkt in Cluster1 mit jedem Punkt in Cluster2.
# - Berechne die euklidische Distanz für jedes Paar.
# - Gib die kleinste gefundene Distanz zurück.
#
# <br>
#
# Im Wesentlichen also:
#
# Sie berechnen, wie nah zwei Cluster beieinander liegen, indem Sie den Abstand zwischen ihrem nächstgelegenen Punktpaar ermitteln.

# %%
def cluster_distance(cluster1, cluster2):
    # TODO: Angenommen, die Cluster sind unendlich weit voneinander entfernt, 
    # vergleiche jeden Punkt aus dem ersten Cluster mit jedem Punkt aus dem zweiten,
    # messe ihre Abstände, behalte das nächstgelegene Paar, das du findest, und gib diesen kleinsten Abstand zurück.
    return ...

# %% [markdown]
# ## Initialisieren Sie Cluster und Tracking-Variablen für hierarchisches Clustering.
#
# In dieser Übung initialisieren Sie das hierarchische Clustering, indem Sie jeden Punkt aus `X` in einen eigenen Cluster einordnen.
# Sie erstellen IDs, um die Cluster zu verfolgen, legen einen Zähler für zukünftig zusammengeführte Cluster fest und bereiten eine leere Liste `Z` vor, um den Verlauf der Zusammenführungen zu speichern.

# %%
#TODO: Setze jeden Punkt X in seinen eigenen Cluster.
clusters = ...

# TODO: Erstelle eine Liste von IDs für alle initialen Cluster.
ids = ...

# TODO: Initialisiere next_id mit der nächsten freien Cluster-ID.
next_id = ...

# TODO: Erstelle eine leere Liste zur Speicherung der Merge-Historie.
Z = ...

# %% [markdown]
# ## Finden Sie das nächstgelegene Clusterpaar (Agglomerationsschritt)
#
# In this exercise, your goal is to identify the two clusters that are closest to each other.
# You must compare every possible pair of clusters, compute their distance using the cluster distance function, and keep track of the smallest distance found.
# At the end, you return the indices of the closest cluster pair together with their distance, so they can be merged in the next step of the algorithm.

# %%
def find_closest_clusters(clusters):
    #TODO: Erstellen Sie eine Variable, die Unendlichkeit speichert.
    min_dist = ...

    #TODO: Erstellen Sie ein Platzhalter-Tupel für das aktuell nächstgelegene Clusterpaar.
    pair = ...

    for i in range(len(clusters)):
        for j in range(i + 1, len(clusters)):

            # TODO: Berechnen Sie die Distanz zwischen clusters[i] und clusters[j].
            dist = ...

            if dist < min_dist:

                # TODO: Aktualisieren Sie min_dist mit der neuen kleineren Distanz.
                min_dist = ...

                # TODO: Speichern Sie die Indizes (i, j) als aktuelles nächstes Clusterpaar.
                pair = ...
    
    # TODO: Geben Sie das nächstgelegene Clusterpaar sowie die minimale Distanz zurück.
    return ..., ...

# %% [markdown]
# ## Führen Sie den Schritt „Agglomerative Merging“ im hierarchischen Clustering durch.
#
# In dieser Übung besteht Ihre Aufgabe darin, die Hauptschleife des agglomerativen hierarchischen Clusterings zu implementieren.
# Solange mehr als ein Cluster existiert, suchen Sie wiederholt die beiden nächstgelegenen Cluster und führen diese zusammen.
# Bei jeder Zusammenführung zeichnen Sie die Zusammenführungsinformationen in Z auf, aktualisieren die Clusterliste und deren IDs, weisen dem zusammengeführten Cluster eine neue ID zu und fahren fort, bis nur noch ein Cluster übrig ist.
# Schließlich konvertieren Sie Z in ein NumPy-Array, damit es die Verknüpfungsmatrix darstellen kann.

# %%
# Der Zusammenführungsprozess wird so lange wiederholt, bis nur noch ein Cluster übrig ist.
while len(clusters) > 1:
    
    # TODO: Finden Sie die zwei nächsten Cluster und deren Distanz.
    (i, j), dist = ...

    #TODO: Speichern Sie die Merge-Information (Cluster-IDs, Distanz, Anzahl Punkte) in der Liste Z.
    Z.append([...])

    # TODO: Erstellen Sie einen neuen Cluster, indem Sie clusters[i] und clusters[j] zusammenführen.
    new_cluster = ... + ...

    # TODO: Entfernen Sie die alten Cluster i und j sowie deren IDs.
    clusters.pop(...)
    clusters.pop(...)
    ids.pop(...)
    ids.pop(...)

    # TODO: Fügen Sie den neuen Cluster zur Liste hinzu.
    clusters.append(...)

    # TODO: Weisen Sie dem neuen Cluster eine neue ID zu.
    ids.append(...)

    # TODO: Erhöhen Sie next_id für den nächsten Merge.
    next_id += ...

# TODO: Konvertieren Sie Z in ein NumPy-Array vom Typ float.
Z = ...

# %%
#TODO: Die Verknüpfungsmatrix ausdrucken
print(...)

# %%
#TODO: Zeichnen Sie das Dendrogramm mit "scipy.cluster.hierarchy import dendrogram"
...

# %% [markdown]
# ## Weitere Lernmaterialien für interessierte Studierende:
#
# https://www.geeksforgeeks.org/machine-learning/hierarchical-clustering/
#
# https://www.w3schools.com/python/python_ml_hierarchial_clustering.asp
#
# https://scikit-learn.org/stable/auto_examples/cluster/plot_agglomerative_dendrogram.html
#
# https://youtu.be/8QCBl-xdeZI?si=EQIqUH46mvU9pobm

# %% [markdown]
# ##### Herzlichen Glückwunsch, du bist jetzt ein Pro im hierarchisches Clustering!!! 🎉🎉🎉
#
#
# (nur wenn du dich auch die Videos und die Lernunterlagen angesehen hast 😊)
#
# (Du solltest das Meme jetzt auch ohne Hilfe selbst verstehen können 🙄)
